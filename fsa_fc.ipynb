# %% [markdown]
# <a href="https://colab.research.google.com/github/tasosnikitakis/Data_Science_Notebooks/blob/main/fsa_fc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random

# %%
# List of player names
player_names = ["Player 1", "Player 2", "Player 3", "Player 4", "Player 5",
                "Player 6", "Player 7", "Player 8", "Player 9", "Player 10",
                "Player 11", "Player 12", "Player 13", "Player 14", "Player 15",
                "Player 16", "Player 17", "Player 18", "Player 19", "Player 20",
                "Player 21", "Player 22", "Player 23", "Player 24", "Player 25",
                "Player 26", "Player 27"]

# List of preferred positions
positions = ["Attacker", "Midfielder", "Defender"]

# Generate random match appearances between 0 and 20 for each player
match_appearances = [random.randint(0, 20) for _ in range(27)]

# Create a dataframe
data = {'Name': player_names, 'Preferred Position': [random.choice(positions) for _ in range(27)], 'Match Appearances': match_appearances}
df = pd.DataFrame(data)

# %%
df
# Out:
#          Name Preferred Position  Match Appearances
# 0    Player 1         Midfielder                 11
# 1    Player 2           Defender                  5
# 2    Player 3           Attacker                 14
# 3    Player 4           Attacker                 17
# 4    Player 5           Attacker                  8
# 5    Player 6           Attacker                 16
# 6    Player 7           Defender                 12
# 7    Player 8           Attacker                  9
# 8    Player 9         Midfielder                 16
# 9   Player 10           Attacker                 11
# 10  Player 11           Attacker                 19
# 11  Player 12           Defender                  2
# 12  Player 13         Midfielder                  3
# 13  Player 14         Midfielder                 15
# 14  Player 15           Defender                  8
# 15  Player 16           Attacker                  2
# 16  Player 17           Defender                 18
# ...

# %%
def split_dataframe_by_positions(dataframe):
    defenders = dataframe[dataframe['Preferred Position'] == 'Defender']
    midfielders = dataframe[dataframe['Preferred Position'] == 'Midfielder']
    attackers = dataframe[dataframe['Preferred Position'] == 'Attacker']

    return defenders, midfielders, attackers

# %%
defenders_df, midfielders_df, attackers_df = split_dataframe_by_positions(df)

# %%
defenders_df
# Out:
#          Name Preferred Position  Match Appearances
# 1    Player 2           Defender                  5
# 6    Player 7           Defender                 12
# 11  Player 12           Defender                  2
# 14  Player 15           Defender                  8
# 16  Player 17           Defender                 18
# 17  Player 18           Defender                  4
# 22  Player 23           Defender                  4
# 24  Player 25           Defender                  5

# %%
midfielders_df
# Out:
#          Name Preferred Position  Match Appearances
# 0    Player 1         Midfielder                 11
# 8    Player 9         Midfielder                 16
# 12  Player 13         Midfielder                  3
# 13  Player 14         Midfielder                 15
# 18  Player 19         Midfielder                  9
# 23  Player 24         Midfielder                 12
# 26  Player 27         Midfielder                 19

# %%
attackers_df
# Out:
#          Name Preferred Position  Match Appearances
# 2    Player 3           Attacker                 14
# 3    Player 4           Attacker                 17
# 4    Player 5           Attacker                  8
# 5    Player 6           Attacker                 16
# 7    Player 8           Attacker                  9
# 9   Player 10           Attacker                 11
# 10  Player 11           Attacker                 19
# 15  Player 16           Attacker                  2
# 19  Player 20           Attacker                 19
# 20  Player 21           Attacker                 15
# 21  Player 22           Attacker                 20
# 25  Player 26           Attacker                 16
