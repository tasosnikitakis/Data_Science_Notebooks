# %% [markdown]
# <a href="https://colab.research.google.com/github/tasosnikitakis/Data_Science_Notebooks/blob/main/pharmacy_expenses_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Imports

# %%
# !pip install dash
# Out:
# Collecting dash
#   Downloading dash-2.13.0-py3-none-any.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 51.3 MB/s eta 0:00:00
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash) (2.2.5)
# Collecting Werkzeug<2.3.0 (from dash)
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 21.2 MB/s eta 0:00:00
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash) (5.15.0)
# Collecting dash-html-components==2.0.0 (from dash)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0 (from dash)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0 (from dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash) (4.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dash) (2.31.0)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting ansi2html (from dash)
#   Downloading ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash) (1.5.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dash) (67.7.2)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<2.3.0,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->dash) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->dash) (23.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from Werkzeug<2.3.0->dash) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2023.7.22)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from retrying->dash) (1.16.0)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, Werkzeug, retrying, ansi2html, dash
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.3.7
#     Uninstalling Werkzeug-2.3.7:
#       Successfully uninstalled Werkzeug-2.3.7
# Successfully installed Werkzeug-2.2.3 ansi2html-1.8.0 dash-2.13.0 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 retrying-1.3.4

# %%
from dash import Dash, dcc, html
from dash.dependencies import Input, Output
from dash.exceptions import PreventUpdate
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import plotly.express as ptx
import plotly.graph_objects as go

# %% [markdown]
# #Dataframe Creation

# %%
expenses_df = pd.read_excel("/content/drive/MyDrive/pharmacy_data/Expenses_2022.xlsx")

# %%
expenses_df.head()
# Out:
#          DATE EXPENSE CATEGORY EXPENSE SUBCATEGORY  EXPENSE
# 0  20/01/2020      ΠΑΓΙΑ ΕΞΟΔΑ             ΕΝΟΙΚΙΟ   400.00
# 1  20/01/2020      ΠΑΓΙΑ ΕΞΟΔΑ            ΤΗΛΕΦΩΝΟ    51.50
# 2  20/01/2020      ΠΑΓΙΑ ΕΞΟΔΑ              KINHTO    23.67
# 3  20/01/2020      ΠΑΓΙΑ ΕΞΟΔΑ               ΡΕΥΜΑ    89.76
# 4  20/01/2020      ΠΑΓΙΑ ΕΞΟΔΑ    ΜΙΣΘΟΣ ΥΠΑΛΛΗΛΟΥ   523.25

# %% [markdown]
# #Data Exploration

# %%
expenses_df.describe()
# Out:
#            EXPENSE
# count   515.000000
# mean    182.646874
# std     182.789277
# min       0.000000
# 25%      54.915000
# 50%     100.000000
# 75%     275.575000
# max    1324.000000

# %%
expenses_df.columns
# Out:
# Index(['DATE', 'EXPENSE CATEGORY', 'EXPENSE SUBCATEGORY', 'EXPENSE'], dtype='object')

# %% [markdown]
# #Data Cleaning

# %%
expenses_df.DATE = pd.to_datetime(expenses_df.DATE, format="%d/%m/%Y")
expenses_df.style.format({"DATE": lambda t: t.strftime("%d/%m/%Y")})
# Out:
# <style type="text/css">
# </style>
# <table id="T_1ea77" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ea77_level0_col0" class="col_heading level0 col0" >DATE</th>
#       <th id="T_1ea77_level0_col1" class="col_heading level0 col1" >EXPENSE CATEGORY</th>
#       <th id="T_1ea77_level0_col2" class="col_heading level0 col2" >EXPENSE SUBCATEGORY</th>
#       <th id="T_1ea77_level0_col3" class="col_heading level0 col3" >EXPENSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ea77_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ea77_row0_col0" class="data row0 col0" >20/01/2020</td>
#       <td id="T_1ea77_row0_col1" class="data row0 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row0_col2" class="data row0 col2" >ΕΝΟΙΚΙΟ</td>
#       <td id="T_1ea77_row0_col3" class="data row0 col3" >400.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1ea77_row1_col0" class="data row1 col0" >20/01/2020</td>
#       <td id="T_1ea77_row1_col1" class="data row1 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row1_col2" class="data row1 col2" >ΤΗΛΕΦΩΝΟ</td>
#       <td id="T_1ea77_row1_col3" class="data row1 col3" >51.500000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1ea77_row2_col0" class="data row2 col0" >20/01/2020</td>
#       <td id="T_1ea77_row2_col1" class="data row2 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row2_col2" class="data row2 col2" >KINHTO</td>
#       <td id="T_1ea77_row2_col3" class="data row2 col3" >23.670000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1ea77_row3_col0" class="data row3 col0" >20/01/2020</td>
#       <td id="T_1ea77_row3_col1" class="data row3 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row3_col2" class="data row3 col2" >ΡΕΥΜΑ</td>
#       <td id="T_1ea77_row3_col3" class="data row3 col3" >89.760000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1ea77_row4_col0" class="data row4 col0" >20/01/2020</td>
#       <td id="T_1ea77_row4_col1" class="data row4 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row4_col2" class="data row4 col2" >ΜΙΣΘΟΣ ΥΠΑΛΛΗΛΟΥ</td>
#       <td id="T_1ea77_row4_col3" class="data row4 col3" >523.250000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1ea77_row5_col0" class="data row5 col0" >20/01/2020</td>
#       <td id="T_1ea77_row5_col1" class="data row5 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row5_col2" class="data row5 col2" >ΠΡΟΜΗΘΕΙΑ POS</td>
#       <td id="T_1ea77_row5_col3" class="data row5 col3" >25.930000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1ea77_row6_col0" class="data row6 col0" >20/01/2020</td>
#       <td id="T_1ea77_row6_col1" class="data row6 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row6_col2" class="data row6 col2" >ΛΟΓΙΣΤΗΣ</td>
#       <td id="T_1ea77_row6_col3" class="data row6 col3" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1ea77_row7_col0" class="data row7 col0" >20/01/2020</td>
#       <td id="T_1ea77_row7_col1" class="data row7 col1" >ΕΚΤΑΚΤΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row7_col2" class="data row7 col2" >ΣΑΚΟΥΛΕΣ</td>
#       <td id="T_1ea77_row7_col3" class="data row7 col3" >33.530000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1ea77_row8_col0" class="data row8 col0" >20/01/2020</td>
#       <td id="T_1ea77_row8_col1" class="data row8 col1" >ΑΣΦΑΛΙΣΤΙΚΕΣ ΕΙΣΦΟΡΕΣ</td>
#       <td id="T_1ea77_row8_col2" class="data row8 col2" >ΤΑΣΟΣ</td>
#       <td id="T_1ea77_row8_col3" class="data row8 col3" >263.620000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1ea77_row9_col0" class="data row9 col0" >20/01/2020</td>
#       <td id="T_1ea77_row9_col1" class="data row9 col1" >ΑΣΦΑΛΙΣΤΙΚΕΣ ΕΙΣΦΟΡΕΣ</td>
#       <td id="T_1ea77_row9_col2" class="data row9 col2" >ΒΙΚΥ (ΙΚΑ+ΕΠΙΚΟΥΡΙΚΑ)</td>
#       <td id="T_1ea77_row9_col3" class="data row9 col3" >301.010000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1ea77_row10_col0" class="data row10 col0" >20/01/2020</td>
#       <td id="T_1ea77_row10_col1" class="data row10 col1" >ΕΠΕΝΔΥΣΕΙΣ</td>
#       <td id="T_1ea77_row10_col2" class="data row10 col2" >ESHOP</td>
#       <td id="T_1ea77_row10_col3" class="data row10 col3" >99.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1ea77_row11_col0" class="data row11 col0" >20/02/2020</td>
#       <td id="T_1ea77_row11_col1" class="data row11 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row11_col2" class="data row11 col2" >ΕΝΟΙΚΙΟ</td>
#       <td id="T_1ea77_row11_col3" class="data row11 col3" >400.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1ea77_row12_col0" class="data row12 col0" >20/02/2020</td>
#       <td id="T_1ea77_row12_col1" class="data row12 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row12_col2" class="data row12 col2" >ΤΗΛΕΦΩΝΟ</td>
#       <td id="T_1ea77_row12_col3" class="data row12 col3" >78.500000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1ea77_row13_col0" class="data row13 col0" >20/02/2020</td>
#       <td id="T_1ea77_row13_col1" class="data row13 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row13_col2" class="data row13 col2" >KINHTO</td>
#       <td id="T_1ea77_row13_col3" class="data row13 col3" >89.450000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1ea77_row14_col0" class="data row14 col0" >20/02/2020</td>
#       <td id="T_1ea77_row14_col1" class="data row14 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row14_col2" class="data row14 col2" >ΡΕΥΜΑ</td>
#       <td id="T_1ea77_row14_col3" class="data row14 col3" >57.940000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1ea77_row15_col0" class="data row15 col0" >20/02/2020</td>
#       <td id="T_1ea77_row15_col1" class="data row15 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row15_col2" class="data row15 col2" >SECURITY  </td>
#       <td id="T_1ea77_row15_col3" class="data row15 col3" >240.680000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1ea77_row16_col0" class="data row16 col0" >20/02/2020</td>
#       <td id="T_1ea77_row16_col1" class="data row16 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row16_col2" class="data row16 col2" >ΜΙΣΘΟΣ ΥΠΑΛΛΗΛΟΥ</td>
#       <td id="T_1ea77_row16_col3" class="data row16 col3" >889.520000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1ea77_row17_col0" class="data row17 col0" >20/02/2020</td>
#       <td id="T_1ea77_row17_col1" class="data row17 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row17_col2" class="data row17 col2" >ΠΡΟΜΗΘΕΙΑ POS</td>
#       <td id="T_1ea77_row17_col3" class="data row17 col3" >20.030000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1ea77_row18_col0" class="data row18 col0" >20/02/2020</td>
#       <td id="T_1ea77_row18_col1" class="data row18 col1" >ΠΑΓΙΑ ΕΞΟΔΑ</td>
#       <td id="T_1ea77_row18_col2" class="data row18 col2" >ΛΟΓΙΣΤΗΣ</td>
#       <td id="T_1ea77_row18_col3" class="data row18 col3" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1ea77_level0_row19"

# %% [markdown]
# ##Monthly expenses categories sums data dataframe creation from main dataframe that contains daily data

# %%
def aggregate_by_year_month_category_sums(expenses_df):
  # Assuming you have your dataframe named 'df'
  # First, convert the 'DATE' column to a datetime format if it's not already
  expenses_df['DATE'] = pd.to_datetime(expenses_df['DATE'], format='%d/%m/%Y')

  # Extract the year and month from the 'DATE' column
  expenses_df['YEAR'] = expenses_df['DATE'].dt.year
  expenses_df['MONTH'] = expenses_df['DATE'].dt.month

  # Group by 'YEAR', 'MONTH', and 'EXPENSE CATEGORY' and sum the 'EXPENSE' column
  aggregated_df = expenses_df.groupby(['YEAR', 'MONTH', 'EXPENSE CATEGORY'])['EXPENSE'].sum().reset_index()

  # Display the aggregated dataframe
  return aggregated_df

# %%
monthly_category_expenses = aggregate_by_year_month_category_sums(expenses_df)

# %%
monthly_category_expenses
# Out:
#      YEAR  MONTH       EXPENSE CATEGORY  EXPENSE
# 0    2020      1  ΑΣΦΑΛΙΣΤΙΚΕΣ ΕΙΣΦΟΡΕΣ   564.63
# 1    2020      1          ΕΚΤΑΚΤΑ ΕΞΟΔΑ    33.53
# 2    2020      1             ΕΠΕΝΔΥΣΕΙΣ    99.00
# 3    2020      1            ΠΑΓΙΑ ΕΞΟΔΑ  1214.11
# 4    2020      2  ΑΣΦΑΛΙΣΤΙΚΕΣ ΕΙΣΦΟΡΕΣ   754.63
# ..    ...    ...                    ...      ...
# 136  2023      6            ΠΑΓΙΑ ΕΞΟΔΑ  1041.58
# 137  2023      7  ΑΣΦΑΛΙΣΤΙΚΕΣ ΕΙΣΦΟΡΕΣ   584.01
# 138  2023      7            ΠΑΓΙΑ ΕΞΟΔΑ  1124.81
# 139  2023      8  ΑΣΦΑΛΙΣΤΙΚΕΣ ΕΙΣΦΟΡΕΣ   584.01
# 140  2023      8            ΠΑΓΙΑ ΕΞΟΔΑ  1493.04
#
# [141 rows x 4 columns]

# %% [markdown]
# ##Aggregation function by year and month creating dataframe with all monthly expenses sums

# %%
def aggregate_by_year_month_sums(expenses_df):
  # Assuming you have your dataframe named 'df'
  # First, convert the 'DATE' column to a datetime format if it's not already
  expenses_df['DATE'] = pd.to_datetime(expenses_df['DATE'], format='%d/%m/%Y')

  # Extract the year and month from the 'DATE' column
  expenses_df['YEAR'] = expenses_df['DATE'].dt.year
  expenses_df['MONTH'] = expenses_df['DATE'].dt.month

  # Group by 'YEAR', 'MONTH' and sum the 'EXPENSE' column
  aggregated_df = expenses_df.groupby(['YEAR', 'MONTH'])['EXPENSE'].sum().reset_index()

  # Display the aggregated dataframe
  return aggregated_df

# %%
monthly_total_expenses_df = aggregate_by_year_month_sums(expenses_df)

# %%
monthly_total_expenses_df
# Out:
#     YEAR  MONTH  EXPENSE
# 0   2020      1  1911.27
# 1   2020      2  2637.73
# 2   2020      3  1456.82
# 3   2020      4  1897.78
# 4   2020      5  1624.00
# 5   2020      6  1303.49
# 6   2020      7  1773.51
# 7   2020      8  1232.10
# 8   2020      9  2616.87
# 9   2020     10  2086.44
# 10  2020     11  3662.35
# 11  2020     12  2196.39
# 12  2021      1  1870.28
# 13  2021      2  2543.69
# 14  2021      3  2667.93
# 15  2021      4  2755.77
# 16  2021      5  2261.21
# 17  2021      6  2216.15
# 18  2021      7  2379.68
# 19  2021      8  3380.59
# 20  2021      9  2285.13
# 21  2021     10  1959.19
# 22  2021     11  3422.91
# 23  2021     12  2590.63
# 24  2022      1  2283.27
# 25  2022      2  1870.09
# 26  2022      3  2119.88
# 27  2022      4  3074.13
# 28  2022      5  1967.33
# 29  2022      6  1810.25
# 30  2022      7  1834.58
# 31  2022      8  1886.16
# 32  2022      9  1745.29
# 33  2022     10  1720.46
# 34  2022     11  1602.14
# 35  2022     12  2061.40
# 36  2023      1  2487.45
# 37  2023      2  1838.47
# 38  2023      3  1693.81
# 39  2023      4  1985.00
# 40  2023      5  1779.04
# 41  2023      6  1786.61
# 42  2023      7  1708.82
# 43  2023      8  2077.05

# %% [markdown]
# ##Aggregation function of total yearly expenses

# %%
def aggregate_by_year_sums(expenses_df):
  # Assuming you have your dataframe named 'df'
  # First, convert the 'DATE' column to a datetime format if it's not already
  expenses_df['DATE'] = pd.to_datetime(expenses_df['DATE'], format='%d/%m/%Y')

  # Extract the year and month from the 'DATE' column
  expenses_df['YEAR'] = expenses_df['DATE'].dt.year

  # Group by 'YEAR' and sum the 'EXPENSE' column
  aggregated_df = expenses_df.groupby('YEAR')['EXPENSE'].sum().reset_index()

  # Display the aggregated dataframe
  return aggregated_df

# %%
yearly_total_expenses_df = aggregate_by_year_sums(expenses_df)

# %%
yearly_total_expenses_df
# Out:
#    YEAR   EXPENSE
# 0  2020  24398.75
# 1  2021  30333.16
# 2  2022  23974.98
# 3  2023  15356.25

# %% [markdown]
# ##Aggregation function to aggreagate by year and expenses subcategory and the sum of expenses

# %%
def aggregate_by_year_subcategory_sums(expenses_df):
  # Assuming you have your dataframe named 'df'
  # First, convert the 'DATE' column to a datetime format if it's not already
  expenses_df['DATE'] = pd.to_datetime(expenses_df['DATE'], format='%d/%m/%Y')

  # Extract the year and month from the 'DATE' column
  expenses_df['YEAR'] = expenses_df['DATE'].dt.year

  # Group by 'YEAR' and 'EXPENSE SUBCATEGORY' summing the 'EXPENSE' column
  aggregated_df = expenses_df.groupby(['YEAR', 'EXPENSE SUBCATEGORY'])['EXPENSE'].sum().reset_index()

  # Display the aggregated dataframe
  return aggregated_df

# %% [markdown]
# ## Function that calculates the total expenses for the current month based on expenses_df DataFrame

# %%
def current_month_total_expenses(expenses_df):
    # Convert the DATE column to datetime if it's not already in that format
    expenses_df['DATE'] = pd.to_datetime(expenses_df['DATE'], format='%d/%m/%Y')

    # Get the current month and year
    current_month = datetime.now().month
    current_year = datetime.now().year

    # Filter the DataFrame for expenses in the current month and year
    filtered_df = expenses_df[
        (expenses_df['DATE'].dt.month == current_month) &
        (expenses_df['DATE'].dt.year == current_year)
    ]

    # Calculate the total expenses for the current month
    total_expenses = filtered_df['EXPENSE'].sum()

    return total_expenses

# %% [markdown]
# ##Function that calculates total expenses for specific year and month that are passed as arguments from expenses_df DataFrame

# %%
def calculate_expenses_for_month_and_year(expenses_df, target_year, target_month):
    # Convert the DATE column to datetime if it's not already in that format
    expenses_df['DATE'] = pd.to_datetime(expenses_df['DATE'], format='%d/%m/%Y')

    # Filter the DataFrame for expenses in the specified year and month
    filtered_df = expenses_df[
        (expenses_df['DATE'].dt.year == target_year) &
        (expenses_df['DATE'].dt.month == target_month)
    ]

    # Calculate the total expenses for the specified month and year
    total_expenses = filtered_df['EXPENSE'].sum()

    return total_expenses

# %%
year_to_calculate = 2020
month_to_calculate = 1
total_expenses = calculate_expenses_for_month_and_year(expenses_df, year_to_calculate, month_to_calculate)
print(f'Total expenses for {month_to_calculate}/{year_to_calculate}: {total_expenses:.2f}')
# Out:
# Total expenses for 1/2020: 1911.27

# %%
aggregate_by_year_subcategory_sums(expenses_df)
# Out:
#      YEAR EXPENSE SUBCATEGORY  EXPENSE
# 0    2020             ANIMAPS   148.80
# 1    2020           BUYCHOICE   101.85
# 2    2020            CLICK.GR    39.70
# 3    2020            COPYSHOP    15.88
# 4    2020           DEALSTORE     8.86
# ..    ...                 ...      ...
# 124  2023               ΡΕΥΜΑ   763.49
# 125  2023            ΣΑΚΟΥΛΕΣ   116.07
# 126  2023               ΤΑΣΟΣ  2142.71
# 127  2023            ΤΗΛΕΦΩΝΟ   807.03
# 128  2023      ΧΑΡΤΙΑ ΜΗΧΑΝΗΣ    14.26
#
# [129 rows x 3 columns]

# %%
df = expenses_df.query("YEAR == 2020")
fig = ptx.pie(df, values='EXPENSE', names='EXPENSE CATEGORY', title='2020 Expenses Categries Pie Chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="40d9ee96-e22f-421c-a1e3-758747d9bf83" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40d9ee96-e22f-421c-a1e3-758747d9bf83")) {                    Plotly.newPlot(                        "40d9ee96-e22f-421c-a1e3-758747d9bf83",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"EXPENSE CATEGORY=%{label}\u003cbr\u003eEXPENSE=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u0395\u039a\u03a4\u0391\u039a\u03a4\u0391 \u0395\u039e\u039f\u0394\u0391","\u0391\u03a3\u03a6\u0391\u039b\u0399\u03a3\u03a4\u0399\u039a\u0395\u03a3 \u0395\u0399\u03a3\u03a6\u039f\u03a1\u0395\u03a3","\u0391\u03a3\u03a6\u0391\u039b\u0399\u03a3\u03a4\u0399\u039a\u0395\u03a3 \u0395\u0399\u03a3\u03a6\u039f\u03a1\u0395\u03a3","\u0395\u03a0\u0395\u039d\u0394\u03a5\u03a3\u0395\u0399\u03a3","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u0395\u039a\u03a4\u0391\u039a\u03a4\u0391 \u0395\u039e\u039f\u0394\u0391","\u0391\u03a3\u03a6\u0391\u039b\u0399\u03a3\u03a4\u0399\u039a\u0395\u03a3 \u0395\u0399\u03a3\u03a6\u039f\u03a1\u0395\u03a3","\u0391\u03a3\u03a6\u0391\u039b\u0399\u03a3\u03a4\u0399\u039a\u0395\u03a3 \u0395\u0399\u03a3\u03a6\u039f\u03a1\u0395\u03a3","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u0395\u039a\u03a4\u0391\u039a\u03a4\u0391 \u0395\u039e\u039f\u0394\u0391","\u0395\u039a\u03a4\u0391\u039a\u03a4\u0391 \u0395\u039e\u039f\u0394\u0391","\u0395\u039a\u03a4\u0391\u039a\u03a4\u0391 \u0395\u039e\u039f\u0394\u0391","\u0395\u039a\u03a4\u0391\u039a\u03a4\u0391 \u0395\u039e\u039f\u0394\u0391","\u0391\u03a3\u03a6\u0391\u039b\u0399\u03a3\u03a4\u0399\u039a\u0395\u03a3 \u0395\u0399\u03a3\u03a6\u039f\u03a1\u0395\u03a3","\u0395\u03a0\u0395\u039d\u0394\u03a5\u03a3\u0395\u0399\u03a3","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u03a0\u0391\u0393\u0399\u0391 \u0395\u039e\u039f\u0394\u0391","\u0395\u039a\u03a4\u0391\u039a\u03a4\u0391 \u0395\u039e\u039f\u0394\u0391","\u0395\u039a\u03a4\u0391\u039a\u03a4\u0391 \u0395\u039e\u039f\u0394\u0391","\u0395\u03a0\u0395\u039d\u0394\u03a5\u03a3\u0395\u0399\u03a3","\u0395\u03a0\u0395\u039d\u0394\u03a5\u03a3\u0395\u0399\u03a3", ...

# %%
filtered_df = expenses_df[(expenses_df['DATE'].dt.year == 2020) & (expenses_df['EXPENSE CATEGORY'] == 'ΠΑΓΙΑ ΕΞΟΔΑ')]
fig = ptx.pie(filtered_df, values='EXPENSE', names='EXPENSE SUBCATEGORY', title='2020 Operating Expenses Pie Chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9b5c4148-98a6-491d-bdae-ce1974439eb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b5c4148-98a6-491d-bdae-ce1974439eb0")) {                    Plotly.newPlot(                        "9b5c4148-98a6-491d-bdae-ce1974439eb0",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"EXPENSE SUBCATEGORY=%{label}\u003cbr\u003eEXPENSE=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["\u0395\u039d\u039f\u0399\u039a\u0399\u039f","\u03a4\u0397\u039b\u0395\u03a6\u03a9\u039d\u039f","KINHTO","\u03a1\u0395\u03a5\u039c\u0391","\u039c\u0399\u03a3\u0398\u039f\u03a3 \u03a5\u03a0\u0391\u039b\u039b\u0397\u039b\u039f\u03a5","\u03a0\u03a1\u039f\u039c\u0397\u0398\u0395\u0399\u0391 POS","\u039b\u039f\u0393\u0399\u03a3\u03a4\u0397\u03a3","\u0395\u039d\u039f\u0399\u039a\u0399\u039f","\u03a4\u0397\u039b\u0395\u03a6\u03a9\u039d\u039f","KINHTO","\u03a1\u0395\u03a5\u039c\u0391","SECURITY  ","\u039c\u0399\u03a3\u0398\u039f\u03a3 \u03a5\u03a0\u0391\u039b\u039b\u0397\u039b\u039f\u03a5","\u03a0\u03a1\u039f\u039c\u0397\u0398\u0395\u0399\u0391 POS","\u039b\u039f\u0393\u0399\u03a3\u03a4\u0397\u03a3","\u0395\u039d\u039f\u0399\u039a\u0399\u039f","\u03a4\u0397\u039b\u0395\u03a6\u03a9\u039d\u039f","KINHTO","\u03a1\u0395\u03a5\u039c\u0391","\u03a0\u03a1\u039f\u039c\u0397\u0398\u0395\u0399\u0391 POS","\u039b\u039f\u0393\u0399\u03a3\u03a4\u0397\u03a3","\u0395\u039d\u039f\u0399\u039a\u0399\u039f","\u03a4\u0397\u039b\u0395\u03a6\u03a9\u039d\u039f","KINHTO","\u03a1\u0395\u03a5\u039c\u0391","\u039c\u0399\u03a3\u0398\u039f\u03a3 \u03a5\u03a0\u0391\u039b\u039b\u0397\u039b\u039f\u03a5","\u03a0\u03a1\u039f\u039c\u0397\u0398\u0395\u0399\u0391 POS","\u039b\u039f\u0393\u0399\u03a3\u03a4\u0397\u03a3","\u0395\u039d\u039f\u0399\u039a\u0399\u039f","\u03a4\u0397\u039b\u0395\u03a6\u03a9\u039d\u039f","KINHTO","\u03a1\u0395\u03a5\u039c\u0391","SECURITY  ","\u03a0\u03a1\u039f\u039c\u0397\u0398\u0395\u0399\u0391 POS","\u039b\u039f\u0393\u0399\u03a3\u03a4\u0397\u03a3","\u0395\u039d\u039f\u0399\u039a\u0399\u039f","\u03a4\u0397\u039b\u0395\u03a6\u03a9\u039d\u039f","KINHTO","\u03a1\u0395\u03a5\u039c\u0391","\u039d\u0395\u03a1\u039f","\u03a0\u03a1\u039f\u039c\u0397\u0398\u0395\u0399\u0391 POS","\u039b\u039f\u0393\u0399\u03a3\u03a4\u0397\u03a3","\u0395\u039d\u039f\u0399\u039a\u0399\u039f","\u03a4\u0397\u039b\u0395\u03a6\u03a9\u039d\u039f","KINHTO","\u03a1\u0395\u03a5\u039c\u0391","SECURITY  ","\u03a0\u03a1\u039f\u039c\u0397\u0398\u0395\u0399\u0391 POS","\u039b\u039f\u0393\u0399\u03a3\u03a4\u0397\u03a3","\u0395\u039d\u039f\u0399\u039a\u0399\u039f","\u03a4\u0397\u039b\u0395\u03a6\u03a9\u039d\u039f","KINHTO","\u03a1\u0395\u03a5\u039c\u0391","\u03a0\u03a1\u039f\u039c\u0397\u0398\u0395\u0399\u0391 POS","\u039b\u039f\u0393\u0399\u03a3\u03a4\u0397\u03a3","\u0395\u039d\u039f\u0399\u039a\u0399\u039f","KINHTO","\u03a1\u0395\u03a5\u039c\u0391","\u039c\u0399\u03a3\u0398\u039f\u03a3 \u03a5\u03a0\u0391\u039b\u039b\u0397\u039b\u039f\u03a5","\u03a0\u03a1\u039f\u039c\u0397\u0398\u0395\u0399\u0391 POS","\u039b\u039f\u0393\u0399\u03a3\u03a4\u0397\u03a3","\u0395\u039d\u039f\u0399\u039a\u0399\u039f","\u03a4\u0397\u039b\u0395\u03a6\u03a9\u039d\u039f","KINHTO","\u03a1\u0395\u03a5\u039c\u0391","\u039d\u0395\u03a1\u039f","SECURITY  ","\u039c\u0399\u03a3\u0398\u039f\u03a3 \u03a5\u03a0\u0391\u039b\u039b\u0397\u039b\u039f\u03a5","\u03a0\u03a1\u039f\u039c\u0397\u0398\u0395\u0399\u0391 POS","\u039b\u039f\u0393\u0399\u03a3\u03a4\u0397\u03a3","\u0395\u039d\u039f\u0399\u039a\u0399\u039f","\u03a4\u0397\u039b\u0395\u03a6\u03a9\u039d\u039f","KINHTO","\u03a1\u0395\u03a5\u039c\u0391","\u039c\u0399\u03a3\u0398\u039f\u03a3 \u03a5\u03a0\u0391\u039b\u039b\u0397\u039b\u039f\u03a5","\u03a0\u03a ...

# %%
filtered_df = expenses_df[(expenses_df['DATE'].dt.year == 2020) & (expenses_df['EXPENSE CATEGORY'] == 'ΕΚΤΑΚΤΑ ΕΞΟΔΑ')]
fig = ptx.pie(filtered_df, values='EXPENSE', names='EXPENSE SUBCATEGORY', title='2020 Non Repeating Operating Expenses Pie Chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="74302185-283a-4cd3-9070-94f06a8bf18d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74302185-283a-4cd3-9070-94f06a8bf18d")) {                    Plotly.newPlot(                        "74302185-283a-4cd3-9070-94f06a8bf18d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"EXPENSE SUBCATEGORY=%{label}\u003cbr\u003eEXPENSE=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["\u03a3\u0391\u039a\u039f\u03a5\u039b\u0395\u03a3","\u03a7\u0391\u03a1\u03a4\u0399\u0391 \u03914","\u03a0\u039f\u0394\u0399\u0391","\u03a3\u0391\u039a\u039f\u03a5\u039b\u0395\u03a3","\u03a7\u0391\u03a1\u03a4\u0399\u0391 \u039c\u0397\u03a7\u0391\u039d\u0397\u03a3","ANIMAPS","\u03a0\u039b\u0395\u039e\u0399\u0393\u039a\u039b\u0391\u03a3","\u039a\u0391\u03a6\u0395\u03a3","\u03a3\u0391\u039a\u039f\u03a5\u039b\u0395\u03a3","\u0395\u03a4\u0399\u039a\u0395\u03a4\u0395\u03a3 DYMO","\u039a\u0391\u03a6\u0395\u03a3","G4S","\u03a3\u0391\u039a\u039f\u03a5\u039b\u0395\u03a3","\u03a3\u03a5\u039d\u0394\u03a1\u039f\u039c\u0397 \u03a6\u03a3\u0391","\u039a\u0391\u03a6\u0395\u03a3","\u03a3\u0391\u039a\u039f\u03a5\u039b\u0395\u03a3","\u0391\u03a1\u03a9\u039c\u0391\u03a4\u0399\u039a\u039f \u03a7\u03a9\u03a1\u039f\u03a5","TAMEIAKH","\u03a3\u0391\u039a\u039f\u03a5\u039b\u0395\u03a3","\u0391\u03a1\u03a9\u039c\u0391\u03a4\u0399\u039a\u039f \u03a7\u03a9\u03a1\u039f\u03a5","\u0391\u039d\u0391\u039b\u03a9\u03a3\u0399\u039c\u0391"],"legendgroup":"","name":"","showlegend":true,"values":[33.53,6.98,34.6,67.79,13.5,148.8,93.0,55.28,33.58,33.48,71.74,77.0,68.22,250.0,66.48,68.22,13.64,80.0,33.58,13.64,11.51],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0 ...

# %%
filtered_df = expenses_df[(expenses_df['DATE'].dt.year == 2020) & (expenses_df['EXPENSE CATEGORY'] == 'ΕΠΕΝΔΥΣΕΙΣ')]
fig = ptx.pie(filtered_df, values='EXPENSE', names='EXPENSE SUBCATEGORY', title='2020 Investment Expenses Pie Chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a5af8bca-56d0-4898-a38e-a3ed554accb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5af8bca-56d0-4898-a38e-a3ed554accb0")) {                    Plotly.newPlot(                        "a5af8bca-56d0-4898-a38e-a3ed554accb0",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"EXPENSE SUBCATEGORY=%{label}\u003cbr\u003eEXPENSE=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["ESHOP","MGMANAGER","PLUS4U","ELECTROHOLIC","BUYCHOICE","LAPTOPPARTS","e-shop","KAPPOUTEL","DEALSTORE","KOOQIE","\u03a0\u039b\u0391\u0399\u03a3\u0399\u039f","INFOQUEST","GERMANOS","GERMANOS","INFOQUEST","\u039b\u0399\u039f\u03a6\u0391\u0393\u039f\u03a3","\u039a\u0391\u03a4\u03a3\u0391\u03a1\u039f\u03a3 ","ONLYMOBILE","ESHOP","ESHOP","ESHOP","COPYSHOP","WEBSUPPLIES","\u039a\u03a9\u03a4\u03a3\u039f\u0392\u039f\u039b\u039f\u03a3","ESHOP","ESHOP","\u0395\u03a1\u039c\u0391\u039d\u039f\u03a3","\u039a\u03a9\u03a4\u03a3\u039f\u0392\u039f\u039b\u039f\u03a3","\u03a0\u039b\u0391\u0399\u03a3\u0399\u039f","ESHOP","\u03a0\u039b\u0391\u0399\u03a3\u0399\u039f","\u03a0\u039b\u0391\u0399\u03a3\u0399\u039f","CLICK.GR","XIAOMISTORE.GR","ELECTROHOLIC","MSYSTEMS","\u03a0\u039b\u0391\u0399\u03a3\u0399\u039f","iRepair","TECHSTORES","VISION STUDIO"],"legendgroup":"","name":"","showlegend":true,"values":[99.0,23.25,79.9,483.8,101.85,35.5,22.9,278.35,8.86,41.4,13.99,129.9,79.91,79.81,77.39,347.2,84.0,103.9,149.0,365.9,45.0,15.88,50.9,8.99,37.8,15.99,8.9,8.94,604.03,101.2,30.98,836.45,39.7,75.69,28.99,79.91,99.0,132.98,42.61,84.88],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth": ...

# %%
filtered_df = expenses_df[(expenses_df['DATE'].dt.year == 2020) & (expenses_df['EXPENSE CATEGORY'] == 'ΑΣΦΑΛΙΣΤΙΚΕΣ ΕΙΣΦΟΡΕΣ')]
fig = ptx.pie(filtered_df, values='EXPENSE', names='EXPENSE SUBCATEGORY', title='2020 Social Security Expenses Pie Chart')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bb0ffa56-b99f-495f-a796-74e81be36b0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb0ffa56-b99f-495f-a796-74e81be36b0b")) {                    Plotly.newPlot(                        "bb0ffa56-b99f-495f-a796-74e81be36b0b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"EXPENSE SUBCATEGORY=%{label}\u003cbr\u003eEXPENSE=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["\u03a4\u0391\u03a3\u039f\u03a3","\u0392\u0399\u039a\u03a5 (\u0399\u039a\u0391+\u0395\u03a0\u0399\u039a\u039f\u03a5\u03a1\u0399\u039a\u0391)","\u03a4\u0391\u03a3\u039f\u03a3","\u0392\u0399\u039a\u03a5 (\u0399\u039a\u0391+\u0395\u03a0\u0399\u039a\u039f\u03a5\u03a1\u0399\u039a\u0391)","\u0392\u0399\u039a\u03a5 (\u0399\u039a\u0391+\u0395\u03a0\u0399\u039a\u039f\u03a5\u03a1\u0399\u039a\u0391)","\u03a4\u0391\u03a3\u039f\u03a3","\u03a4\u0391\u03a3\u039f\u03a3","\u0392\u0399\u039a\u03a5 (\u0399\u039a\u0391+\u0395\u03a0\u0399\u039a\u039f\u03a5\u03a1\u0399\u039a\u0391)","\u03a4\u0391\u03a3\u039f\u03a3","\u03a4\u0391\u03a3\u039f\u03a3","\u0392\u0399\u039a\u03a5 (\u0399\u039a\u0391+\u0395\u03a0\u0399\u039a\u039f\u03a5\u03a1\u0399\u039a\u0391)","\u03a4\u0391\u03a3\u039f\u03a3","\u0392\u0399\u039a\u03a5 (\u0399\u039a\u0391+\u0395\u03a0\u0399\u039a\u039f\u03a5\u03a1\u0399\u039a\u0391)","\u03a4\u0391\u03a3\u039f\u03a3","\u0392\u0399\u039a\u03a5 (\u0399\u039a\u0391+\u0395\u03a0\u0399\u039a\u039f\u03a5\u03a1\u0399\u039a\u0391)","\u03a4\u0391\u03a3\u039f\u03a3","\u0392\u0399\u039a\u03a5 (\u0399\u039a\u0391+\u0395\u03a0\u0399\u039a\u039f\u03a5\u03a1\u0399\u039a\u0391)"],"legendgroup":"","name":"","showlegend":true,"values":[263.62,301.01,263.62,491.01,429.09,166.5,199.0,71.68,253.24,263.62,283.04,263.62,283.04,263.62,283.04,248.0,283.04],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444 ...
